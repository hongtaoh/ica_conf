# %% [markdown]
# The purpose of this paper is to refine authors and sessions.
#
# Basically, i want to know how many papers, affs, etc are associated with each author.
#
# For sessions, i want to know how many papers are in that session.

# %%
import pandas as pd 
import numpy as np 
from json import loads, dumps

# %% [markdown]
# ## Papers

# %%
papers = pd.read_csv('../data/processed/papers.csv')
papers.columns = ['paper_id', 'title', 'type', 'abstract', 'number_of_authors', 'year', 'session', 'division', 'authors']
papers.drop(['authors'], inplace=True, axis = 1)
papers.head()
# Out:
#     paper_id                                              title   type  \
# 0  2003-0001  Access to the Media Versus Access to Audiences...  Paper
# 1  2003-0002  Accounting Episodes as Communicative Practice ...  Paper
# 2  2003-0003        Accounts of Single-fatherhood: A case study  Paper
# 3  2003-0004  A Challenge to the Duel: Socializing Dedicated...  Paper
# 4  2003-0005  A chatroom ethnography: Evolution of community...  Paper
#
#                                             abstract  number_of_authors  year  \
# 0  When the issue of speakers' rights of access a...                1.0  2003
# 1  In this paper I describe accounting episodes a...                1.0  2003
# 2  Abstract\nRelying on single-fathers accounts ...                4.0  2003
# 3  This paper explores the structural controls av...                1.0  2003
# 4  In creating an ethnography about the City, Tex...                1.0  2003
#
#   session division
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN

# %%
paper_json = loads(papers.to_json(orient='records'))
paper_json[0]
# Out:
# {'paper_id': '2003-0001',
#  'title': 'Access to the Media Versus Access to Audiences: The Distinction and its Implications for Media Regulation and Policy',
#  'type': 'Paper',
#  'abstract': 'When the issue of speakers\' rights of access arises in media regulation and policy contexts, the focus typically is on the concept of speakers\' rights of access "to the media," or "to the press." This right typically is premised on the audience\'s need for access to diverse sources and content. In contrast, in many non-mediated contexts, the concept of speakers\' rights of access frequently is defined in terms of the speaker\'s own First Amendment right of access to audiences. This paper explores the distinctions between these differing interpretations of a speaker\'s access rights and argues that the concept of a speaker\'s right of access to audiences merits a more prominent position in media regulation and policy. This paper then explores the implications of such a shift in perspective for media regulation and policy-making.',
#  'number_of_authors': 1.0,
#  'year': 2003,
#  'session': None,
#  'division': None}

# %%
authors = pd.read_csv('../data/processed/authors.csv')
authors.head()
# Out:
#     Paper ID                                              Title  \
# 0  2003-0001  Access to the Media Versus Access to Audiences...
# 1  2003-0002  Accounting Episodes as Communicative Practice ...
# 2  2003-0003        Accounts of Single-fatherhood: A case study
# 3  2003-0003        Accounts of Single-fatherhood: A case study
# 4  2003-0003        Accounts of Single-fatherhood: A case study
#
#    Number of Authors  Author Position           Author Name  \
# 0                  1                1         Philip Napoli
# 1                  1                1         Mariko Kotani
# 2                  4                1  Tara M Emmers-Sommer
# 3                  4                2            David Rhea
# 4                  4                3        Laura Triplett
#
#          Author Affiliation  Year
# 0                 Fordham U  2003
# 1  Aoyama Gakuin University  2003
# 2     University of Arizona  2003
# 3     University of Arizona  2003
# 4     University of Arizona  2003

# %%
authorship_dict = {}
paperid_authors_dic = {}
# for every paper
for paper_id, group in authors.groupby('Paper ID'):
    paperid_authors_dic[paper_id] = list(group['Author Name'])
    authorships = []
    author_names = group['Author Name'].tolist()
    affs = group['Author Affiliation'].tolist()
    for i, author_name in enumerate(author_names):
        dic = {}
        dic['position'] = i
        dic['author_name'] = author_name 
        dic['author_affiliation'] = affs[i]
        authorships.append(dic)
    authorship_dict[paper_id] = authorships

# %%
authorship_dict['2003-0001']
# Out:
# [{'position': 0,
#   'author_name': 'Philip Napoli',
#   'author_affiliation': 'Fordham U'}]

# %%
for paper_dic in paper_json:
    try:
        paper_dic['authorships'] = authorship_dict[paper_dic['paper_id']]
        paper_dic['author_names'] = paperid_authors_dic[paper_dic['paper_id']]
    except:
        print(paper_dic)
# Out:
# {'paper_id': '2005-0806', 'title': 'Interpersonal and Intrapersonal Motives to Acquire Information from Mediated Messages', 'type': 'Paper', 'abstract': 'The present investigation explores the influences of interpersonal (intrinsic) and intrapersonal (extrinsic) motives on information acquisition from mediated messages, as well as the influences these motives may have on each other. Intrinsic and extrinsic motives were operationalized as personal interest and expectations of future relevant discussion, respectively. Respondents received a manipulation that elevated the expectation of discussing certain topics with unknown students and then viewed a newscast featuring these topics. Personal interest in and information acquisition of each message were assessed, along with anticipations of topical discussion with friends or family. Results showed that intrinsic and extrinsic interests related positively to information acquisition indicators for the relevant news stories. In addition, extrinsic motives were found to influence intrinsic motives. Implications for viewing traditional media effects research in conjunction with epistemic motivation research are discussed.', 'number_of_authors': None, 'year': 2005, 'session': 'Why and How We Communication: The Role of Motivation', 'division': 'Information Systems'}
# {'paper_id': '2005-0858', 'title': '\x93Just Like Independence Day!\x94 The Falling Towers On 9/11 and the Hegemonic Function of Intertextuality', 'type': 'Paper', 'abstract': 'The focus of this study is to illustrate how the movie Independence Day served as a hegemonic\nvehicle for unobtrusively reinforcing the Bush administration\x92s interpretive framework of the\n9/11 events. The basis for this argument subsists in the numerous intertextual references to the\nmovie that appeared in mainstream media sources from the outset of the tragedy. Following\nKellner\x92s (1995) concept of \x93ideological critique,\x94 I first examine the narrative of Independence\nDay through a comparison with Fight Club. Both movies portray analogous scenes of crumbling\ntowers but in two different ideological contexts, which the comparison intends to highlight.\nSecond, I examine the ideological subtext of Independence Day with those of two key speeches\ngiven by president Bush. This second \x91diagnostic\x92 comparison offers evidence that similar\nideologies underlie the narrative in Independence Day and Bush\x92s speeches. I argue, therefore,\nthat the intertextual references between Independence Day and the World Trade Center tragedy\nwere functional in activating and promoting the hegemonic ascent of an interpretive framework\nthat is consistent with the one proposed by the Bush administration.', 'number_of_authors': None, 'year': 2005, 'session': 'Intertextual Narratives of Time and Space', 'division': 'Popular Communication'}
# {'paper_id': '2005-1225', 'title': 'Reality Check of Perceived Conflicts: Experienced Conflicts by Public Relations Practitioners and Journalists', 'type': 'Paper', 'abstract': 'In a national survey of 641 public relations practitioners and journalists using crisis communication strategies and conflict-cooperation scales, two professions reported experiencing verbal and behavioral conflicts in the source-reporter relationship. While both professions reported their experience of the behavioral conflicts in the relationship, they demonstrated discrepancies in experiences of \x91grant privilege to the other profession,\x92 \x92promise material support,\x92 \x92give additional assistance\x92 and other experiences related to \x91confer\x92 behaviors. Public relations practitioners reported \x91confer\x92 events in the source-reporter relationship more than did journalists. This study confirms the perceived conflicts of public relations professionals and journalists through their behavioral conflicts and reflects that journalists do not tend to admit the information subsidy function of public relations practitioners.', 'number_of_authors': None, 'year': 2005, 'session': 'Public Relations Plenary Interactive Paper Session', 'division': 'Public Relations'}
# {'paper_id': '2007-1020', 'title': 'New Media and the Middle East', 'type': 'Session Paper', 'abstract': 'Scheduled Time: Sun May 27 2007, 12:00 to 1:15pm   Building/Room: Hilton Hotel, Grand Ballroom\nIn Session Submission: International & Development Communication Interactive Paper Session', 'number_of_authors': None, 'year': 2007, 'session': 'International & Development Communication Interactive Paper Session', 'division': 'Intercultural & Development Communication'}

# %%
paper_json[2000]
# Out:
# {'paper_id': '2004-1007',
#  'title': 'Traveling Through Borders: SARS Coverage in a Chinese-Language Newspaper in the U.S.',
#  'type': 'Paper',
#  'abstract': 'A public crisis like SARS poses an immediate and serious threat to the lives and property and to the peace of mind of many. As the crisis unfolds, the mass media are called upon to keep both public officials and the general population abreast of the situation. This study focuses on news coverage of SARS, a public health crisis that had an enormous global impact. Drawing upon Media Dependency System theory, we examined a Chinese-language newspaper, a well read publication in the Chinese community in the U.S., with concerned readers about the happenings in their home countries where SARS originated. The findings suggested that the paper cited less health-related sources than health-related sources when reporting SARS stories. In addition, more government organizations were cited than regular individuals. There were only few stories that provide \x93news you can use.\x94 While it is the newspaper\x92s goal to cite credible sources and to meet their social responsibilities in times of crisis, our results suggest that they might not be living up to their promise.',
#  'number_of_authors': 4.0,
#  'year': 2004,
#  'session': None,
#  'division': None,
#  'authorships': [{'position': 0,
#    'author_name': 'Linda Alexander',
#    'author_affiliation': 'U of Southern California'},
#   {'position': 1, 'author_name': 'Hao Huang', 'author_affiliation': 'USC'},
#   {'position': 2, 'author_name': 'Wan-Ying Lin', 'author_affiliation': 'USC'},
#   {'position': 3,
#    'author_name': 'Lu Tang',
#    'author_affiliation': 'University of Southern California'}],
#  'author_names': ['Linda Alexander', 'Hao Huang', 'Wan-Ying Lin', 'Lu Tang']}

# %% [markdown]
# ## Author aggregated

# %%
dicts = []
for author_name, group in authors.groupby('Author Name'):
    # sort by year to make sure affs are in temporal order 
    group.sort_values('Year', ascending=True, inplace=True)
    paper_ids = group['Paper ID'].unique()
    affs = group['Author Affiliation'].unique()
    years = group['Year'].unique()
    dic = {
        'Author Name': author_name,
        'Year Count': len(years),
        'Affiliation Count': len(affs),
        'Paper Count': len(paper_ids),
        'Paper IDs': ", ".join(map(str, paper_ids)),
        'Years': ", ".join(map(str, years)),
        'Affiliations': " -> ".join(map(str, affs))
    }
    dicts.append(dic)

# %%
dicts[0:2]
# Out:
# [{'Author Name': '"Kathy" Feng Li',
#   'Year Count': 1,
#   'Affiliation Count': 1,
#   'Paper Count': 1,
#   'Paper IDs': '2005-1018',
#   'Years': '2005',
#   'Affiliations': 'U of Houston'},
#  {'Author Name': '. Sunwolf',
#   'Year Count': 1,
#   'Affiliation Count': 1,
#   'Paper Count': 1,
#   'Paper IDs': '2011-0102',
#   'Years': '2011',
#   'Affiliations': 'Santa Clara U'}]

# %%
pd.DataFrame(dicts[0:100]).sort_values(by='Year Count', ascending=False)
# Out:
#                Author Name  Year Count  Affiliation Count  Paper Count  \
# 28              Aaron Shaw           7                  5           12
# 88          Adam J. Saffer           6                  5           11
# 16  Aaron Castelan Cargile           5                  1            8
# 26       Aaron S. Veenstra           5                  4            8
# 6         A Susana Ramirez           4                  3            4
# ..                     ...         ...                ...          ...
# 39      Abby Leigh Prestin           1                  1            1
# 38      Abby Gail LeGrange           1                  1            1
# 36         Abbey Levenshus           1                  1            1
# 34         Abbe S Depretis           1                  1            1
# 99              Adam Mason           1                  1            1
#
#                                             Paper IDs  \
# 28  2011-0152, 2011-0393, 2012-1663, 2013-1676, 20...
# 88  2012-0498, 2013-1492, 2015-0066, 2015-0067, 20...
# 16  2007-0024, 2008-0887, 2008-1712, 2012-1021, 20...
# 26  2008-0380, 2010-0221, 2010-0993, 2013-0327, 20...
# 6          2008-0191, 2009-0744, 2011-0530, 2014-0930
# ..                                                ...
# 39                                          2009-0491
# 38                                          2007-0601
# 36                                          2008-1301
# 34                                          2013-0333
# 99                                          2016-1579
#
#                                        Years  \
# 28  2011, 2012, 2013, 2014, 2016, 2017, 2018
# 88        2012, 2013, 2015, 2016, 2017, 2018
# 16              2007, 2008, 2012, 2015, 2017
# 26              2008, 2010, 2013, 2015, 2018
# 6                     2008, 2009, 2011, 2014
# ..                                       ...
# 39                                      2009
# 38                                      2007
# 36                                      2008
# 34                                      2013
# 99                                      2016
#
#                                          Affiliations
# 28  University of California, Berkeley -> U of Cal...
# 88  University of Oklahoma -> U of Oklahoma -> U o...
# 16                                 California State U
# 26  U of Wisconsin - Madison -> Southern Illinois ...
# 6   U of Pennsylvania -> Harvard University -> Uni...
# ..                                                ...
# 39                    U of California - Santa Barbara
# 38                                       U of Florida
# 36                                         American U
# 34                              Christopher Newport U
# 99                          Illinois State University
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Work on sessions

# %%
# papers = pd.read_csv('../data/processed/papers.csv')
# papers.head()

# %%
# dic = {}
# for session, group in papers.dropna(subset=['Session']).groupby('Session'):
#     dic[session] = len(group)

# %%
# len(papers.Session.unique())

# %%
# dic['So Far, So Good, Part 2: Organizational Communication Research Escalator']

# %%
sessions = pd.read_csv('../data/processed/sessions.csv')
sessions.head()
# Out:
#    Year   Session Type                                      Session Title  \
# 0  2014  Paper Session                     Meda Coverage of Health Issues
# 1  2014  Paper Session                               Cognition and Health
# 2  2014  Paper Session  Changing the News 140 Characters At a Time: Tw...
# 3  2014  Paper Session  Media and Political Contestation in Greater China
# 4  2014  Paper Session  Between Science and the Public: Studies in Sci...
#
#                             Division/Unit        Chair Name  \
# 0                    Health Communication        Xiaoli Nan
# 1                    Health Communication      Seth M. Noar
# 2                      Journalism Studies     Seth C. Lewis
# 3  Global Communication and Social Change       Guobin Yang
# 4                      Journalism Studies  Henrik Ornebring
#
#             Chair Affiliation
# 0               U of Maryland
# 1         U of North Carolina
# 2              U of Minnesota
# 3  University of Pennsylvania
# 4                  Karlstad U

# %%
sessions.shape
# Out:
# (1859, 6)

# %% [markdown]
# So, clearly some sessions in papers are not present in the dataset of `sessions`. Let's address this.

# %%
# sessions['Paper Count'] = sessions['Session Title'].apply(lambda x : dic[x])

# %% [markdown]
# ## Add to papers
#
# First, let's convert sessions to a dic and add info to papers.

# %%
session_dic = {}
for session, group in sessions.groupby('Session Title'):
    dic = {}
    dic['session'] = session
    dic['session_type'] = group['Session Type'].tolist()[0]
    dic['chair_name'] = group['Chair Name'].tolist()[0]
    dic['chair_affiliation'] = group['Chair Affiliation'].tolist()[0]
    dic['division'] = group['Division/Unit'].tolist()[0]
    session_dic[session] = dic

# %%
# session_dic

# %%
session_dic['Sports Communication Interactive Poster Session']
# Out:
# {'session': 'Sports Communication Interactive Poster Session',
#  'session_type': 'Interactive Paper Session',
#  'chair_name': nan,
#  'chair_affiliation': nan,
#  'division': 'In Event: ICA Plenary Interactive Paper/Poster Session II'}

# %%
for paper_dic in paper_json:
    try:
        paper_dic['session_info'] = session_dic[paper_dic['session']]
    except:
        pass

# %%
paper_json[-1]
# Out:
# {'paper_id': '2018-0255',
#  'title': 'The Impact of Presenting Physiological Data During Sporting Events on Audiences Entertainment',
#  'type': 'Poster',
#  'abstract': 'Psychophysiological data has been useful in many domains and this study examines the use of such information in the domain of sports audiences. This study employs a four condition experiment in which participants watched a short sports clip displaying different physiological measures in the corner. The participants were then asked about their perceptions of the clip. Broadly, there was not much difference between groups based on the types of information presented, however, presenting blood pressure information proved to be the most entertaining for audiences. This provides early evidence that the presentation of physiological information during a sporting event can impact feelings of enjoyment, meaningfulness, and perceptions of knowledge of the sport. There is promise for these measures to be used in sports media provided that best practices are followed and attention is paid to important factors.',
#  'number_of_authors': 1.0,
#  'year': 2018,
#  'session': 'Sports Communication Interactive Poster Session',
#  'division': 'In Event: ICA Interactive Paper/Poster Session III',
#  'authorships': [{'position': 0,
#    'author_name': 'Yu-Hao Lee',
#    'author_affiliation': 'University of Florida'},
#   {'position': 1,
#    'author_name': 'Dave Mclean',
#    'author_affiliation': 'U of Florida'},
#   {'position': 2,
#    'author_name': 'Bruce Getz',
#    'author_affiliation': 'U of Florida'},
#   {'position': 3,
#    'author_name': 'Ryan Rogers',
#    'author_affiliation': 'Butler University'}],
#  'author_names': ['Yu-Hao Lee', 'Dave Mclean', 'Bruce Getz', 'Ryan Rogers'],
#  'session_info': {'session': 'Sports Communication Interactive Poster Session',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'In Event: ICA Plenary Interactive Paper/Poster Session II'}}

# %% [markdown]
# ## Aggregated Session data
#
# - division
# - chair_name
# - chair_affiliation
# - type
# - paper_count
# - years

# %%
papers.head()
# Out:
#     paper_id                                              title   type  \
# 0  2003-0001  Access to the Media Versus Access to Audiences...  Paper
# 1  2003-0002  Accounting Episodes as Communicative Practice ...  Paper
# 2  2003-0003        Accounts of Single-fatherhood: A case study  Paper
# 3  2003-0004  A Challenge to the Duel: Socializing Dedicated...  Paper
# 4  2003-0005  A chatroom ethnography: Evolution of community...  Paper
#
#                                             abstract  number_of_authors  year  \
# 0  When the issue of speakers' rights of access a...                1.0  2003
# 1  In this paper I describe accounting episodes a...                1.0  2003
# 2  Abstract\nRelying on single-fathers accounts ...                4.0  2003
# 3  This paper explores the structural controls av...                1.0  2003
# 4  In creating an ethnography about the City, Tex...                1.0  2003
#
#   session division
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN

# %%
papers[papers.session=='"...And Communications for All:" A Policy Agenda for the New Administration']
# Out:
#        paper_id                                              title  \
# 8118  2009-0069        Americas Forgotten Challenge: Rural Access
# 8368  2009-0319  Creating a Media Policy Agenda for the Digital...
# 8429  2009-0380  Digital Media, Modern Democracy, and Our Trunc...
# 8814  2009-0765  International Benchmarks: The Crisis in U.S. C...
# 9258  2009-1209  Public Scholarship and the Communications Poli...
# 9320  2009-1271       Rethinking the Media Ownership Policy Agenda
#
#                type                                           abstract  \
# 8118  Session Paper  Roughly 17 percent of the U.S. population live...
# 8368  Session Paper  The rapid growth of the Internet and prolifera...
# 8429  Session Paper  Policy makers and regulators in the new admini...
# 8814  Session Paper  This presentation, will set out by describing ...
# 9258  Session Paper  Communications has been at the heart of our sp...
# 9320  Session Paper  Media ownership is a policy issue with a long ...
#
#       number_of_authors  year  \
# 8118                1.0  2009
# 8368                1.0  2009
# 8429                1.0  2009
# 8814                1.0  2009
# 9258                1.0  2009
# 9320                1.0  2009
#
#                                                 session  \
# 8118  "...And Communications for All:" A Policy Agen...
# 8368  "...And Communications for All:" A Policy Agen...
# 8429  "...And Communications for All:" A Policy Agen...
# 8814  "...And Communications for All:" A Policy Agen...
# 9258  "...And Communications for All:" A Policy Agen...
# 9320  "...And Communications for All:" A Policy Agen...
#
#                         division
# 8118  Communication Law & Policy
# 8368  Communication Law & Policy
# 8429  Communication Law & Policy
# 8814  Communication Law & Policy
# 9258  Communication Law & Policy
# 9320  Communication Law & Policy

# %%
'"...And Communications for All:" A Policy Agenda for the New Administration' in session_dic
# Out:
# False

# %%
for session, group in papers.groupby('session'):
    # groupby excludes rows with nan values
    if session in session_dic:
        session_dic[session]['years'] = list(group.year.unique())
        session_dic[session]['paper_count'] = len(group)
    else:
        dic = {}
        dic['session'] = session
        dic['years'] = list(group.year.unique())
        dic['paper_count'] = len(group)
        dic['session_type'] = np.nan 
        dic['chair_name'] = np.nan 
        dic['chair_affiliation'] = np.nan
        try:
            dic['division'] = group.division
        except:
            dic['division'] = np.nan
        session_dic[session] = dic

# %%
list(session_dic.values())
# Out:
# [{'session': '"Let\'s Research It All!" New Approaches for Video Games and Their Effects',
#   'session_type': 'Paper Session',
#   'chair_name': 'Johannes Breuer',
#   'chair_affiliation': 'GESIS – Leibniz-Institute for the Social Sciences',
#   'division': 'Game Studies',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': '#SocialSports: Digital Media Technologies and Sports Communication',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Sports Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': "(Don't) Be So Emotional: Athletes, Professors, and Other Publics",
#   'session_type': 'Paper Session',
#   'chair_name': 'Vilma L. Luoma-aho',
#   'chair_affiliation': 'University of Jyvaskyla',
#   'division': 'Public Relations',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': '@Journalists on #Twitter',
#   'session_type': 'Paper Session',
#   'chair_name': 'Shannon C McGregor',
#   'chair_affiliation': 'University of Utah',
#   'division': 'Journalism Studies',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'A Focus On Instructors',
#   'session_type': 'Paper Session',
#   'chair_name': 'Davi Kallman',
#   'chair_affiliation': 'Washington State U',
#   'division': 'Instructional & Developmental Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'A Much Anticipated Release: Exploring Reactions to Fifty Shades on Film',
#   'session_type': 'Paper Session',
#   'chair_name': 'Melissa A. Click',
#   'chair_affiliation': 'U of Missouri - Columbia',
#   'division': 'Feminist Scholarship',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'A Potpourri of Framing Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Andreas Schuck',
#   'chair_affiliation': 'U of Amsterdam',
#   'division': 'Political Communication',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'A World of Good: Diversity and Culture in Organizational Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Kumi Ishii',
#   'chair_affiliation': 'Western Kentucky University',
#   'division': 'Organizational Communication',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Activism for Changes in Society',
#   'session_type': 'Paper Session',
#   'chair_name': 'Kim A. Johnston',
#   'chair_affiliation': 'Queensland U of Technology (QUT)',
#   'division': 'Public Relations',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Activism, Advocacy, and Civil Society',
#   'session_type': 'Paper Session',
#   'chair_name': 'Aimei Yang',
#   'chair_affiliation': 'University of Southern California',
#   'division': 'Public Relations',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Activism, Communication and Social Justice Interactive Poster Session',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'In Event: ICA Interactive Paper/Poster Session I',
#   'years': [2018],
#   'paper_count': 8},
#  {'session': 'Activist Interventions: Community Resilience and Resistance',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Public Relations',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Addiction to Communication Technologies',
#   'session_type': 'Paper Session',
#   'chair_name': 'Emmelyn Adriana Justine Croes',
#   'chair_affiliation': 'Tilburg University',
#   'division': 'Communication and Technology',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Adolescent and Youth Social Media Behaviors',
#   'session_type': 'Paper Session',
#   'chair_name': 'danah michele boyd',
#   'chair_affiliation': 'Microsoft Research',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Adolescents and Media: Working Toward Adulthood',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Children Adolescents and the Media',
#   'years': [2016],
#   'paper_count': 9},
#  {'session': 'Adolescents, Family, Aging: High Density Panel in Health Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Julia C.M. van Weert',
#   'chair_affiliation': 'ASCoR',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 7},
#  {'session': 'Advancements in Political Journalism Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Christian Baden',
#   'chair_affiliation': 'Hebrew U of Jerusalem',
#   'division': 'Political Communication',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Advances and Challenges in Media Literacy Scholarship',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Children Adolescents and the Media',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advances in Advertising Research (TOP PAPER ENTRY)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Osei Appiah',
#   'chair_affiliation': 'Ohio State U',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in Agenda Setting Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Wayne Wanta',
#   'chair_affiliation': 'U of Florida',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in Audience Research',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Rachel L. Bailey',
#   'chair_affiliation': 'Washington State University',
#   'division': 'Information Systems',
#   'years': [2016],
#   'paper_count': 8},
#  {'session': 'Advances in Content Analysis',
#   'session_type': 'Paper Session',
#   'chair_name': 'Mark Boukes',
#   'chair_affiliation': 'University of Amsterdam / ASCoR',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in Entertainment Media Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Yariv Tsfati',
#   'chair_affiliation': 'U of Haifa',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Advances in Family Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Tamara D. Afifi',
#   'chair_affiliation': 'U of Iowa',
#   'division': 'Interpersonal Communication',
#   'years': [2014],
#   'paper_count': 6},
#  {'session': 'Advances in Framing Effects Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Kimberly A. Gross',
#   'chair_affiliation': 'George Washington U',
#   'division': 'Political Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Advances in Framing Research: Content Analyses',
#   'session_type': 'Paper Session',
#   'chair_name': 'David Tewksbury',
#   'chair_affiliation': 'U of Illinois at Urbana–Champaign',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in Framing Research: Experimentation',
#   'session_type': 'Paper Session',
#   'chair_name': 'Erik P. Bucy',
#   'chair_affiliation': 'Texas Tech U',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Advances in Measurement and Methodology',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Emily Falk',
#   'chair_affiliation': 'University of Pennsylvania',
#   'division': 'Information Systems',
#   'years': [2014],
#   'paper_count': 8},
#  {'session': 'Advances in Network Analysis',
#   'session_type': 'Paper Session',
#   'chair_name': 'Winson Peng',
#   'chair_affiliation': 'Michigan State U',
#   'division': 'Computational Methods',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Advances in Public Opinion Research (TOP PAPER ENTRY)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Benjamin H. Detenber',
#   'chair_affiliation': 'Nanyang Technological U',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in Text Analysis Methods',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Computational Methods',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Advances in Third Person Effect Research (TOP PAPER ENTRY)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Albert C. Gunther',
#   'chair_affiliation': 'U of Wisconsin-Madison',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in Third-Person Effects Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Benjamin H. Detenber',
#   'chair_affiliation': 'Nanyang Technological U',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advances in Visual Communication Studies: New Challenges and New Frameworks',
#   'session_type': 'Paper Session',
#   'chair_name': 'Katharina Lobinger',
#   'chair_affiliation': 'University of Bremen',
#   'division': 'Visual Communication Studies',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in the Study of Advertising and Branding',
#   'session_type': 'Paper Session',
#   'chair_name': 'Carmen Stitt',
#   'chair_affiliation': 'California State U - Sacramento',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advances in the Study of Audience Engagement With the News',
#   'session_type': 'Paper Session',
#   'chair_name': 'Stephanie Edgerly',
#   'chair_affiliation': 'Northwestern U',
#   'division': 'Journalism Studies',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Advances in the Study of Entertainment Media',
#   'session_type': 'Paper Session',
#   'chair_name': "Charisse L'Pree Corsbie-Massay",
#   'chair_affiliation': 'Syracuse University',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advances in the Study of Film',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nicholas David Bowman',
#   'chair_affiliation': 'West Virginia U',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advances in the Study of Risk and Crisis Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Shawnika Jeanine Hull',
#   'chair_affiliation': 'U of Wisconsin-Madison',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Advances in the Study of Science Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Teresa Lynch',
#   'chair_affiliation': 'Indiana University',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advancing Feminist Theories: Interventions, Integrations, and Intersections',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Feminist Scholarship',
#   'years': [2017],
#   'paper_count': 6},
#  {'session': 'Advancing Research on Trust in the News',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nayla Fawzi',
#   'chair_affiliation': 'U of Munich',
#   'division': 'Journalism Studies',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Advancing Scholarship, Methods, and Policy on Digital Inequality and Marginalized Populations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Linda Royall',
#   'chair_affiliation': 'Oral Roberts University',
#   'division': 'Communication and Technology',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Advancing Theory Building in Mass Communication Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Erik P. Bucy',
#   'chair_affiliation': 'Texas Tech University',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advertising and Branding',
#   'session_type': 'Paper Session',
#   'chair_name': 'Mark Allen Hamilton',
#   'chair_affiliation': 'U of Connecticut',
#   'division': 'Information Systems',
#   'years': [2017, 2016],
#   'paper_count': 16},
#  {'session': 'Advertising and Consumer Behavior',
#   'session_type': 'Paper Session',
#   'chair_name': 'Denis Wu',
#   'chair_affiliation': 'Boston U',
#   'division': 'Mass Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Advertising and Privacy',
#   'session_type': 'Paper Session',
#   'chair_name': 'Rebecca A. Hayes',
#   'chair_affiliation': 'Illinois State University',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Advertising, Narratives, and Message Framing',
#   'session_type': 'Paper Session',
#   'chair_name': 'Michal Hershman Shitrit',
#   'chair_affiliation': 'U of Haifa',
#   'division': 'Mass Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Affect and Emotion in Mass Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Robin Nabi',
#   'chair_affiliation': 'U of California - Santa Barbara',
#   'division': 'Mass Communication',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Africa and African Ethnicity and Race Concerns',
#   'session_type': 'Paper Session',
#   'chair_name': 'Anamik Saha',
#   'chair_affiliation': 'Goldsmiths',
#   'division': 'Ethnicity and Race in Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Agency and Influence in Organizational Contexts',
#   'session_type': 'Paper Session',
#   'chair_name': 'ward van zoonen',
#   'chair_affiliation': 'University of Amsterdam',
#   'division': 'Organizational Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Aggression, Bullying, and Fear in a Media-Rich Environment: High-Density Session',
#   'session_type': 'Paper Session',
#   'chair_name': 'Erica L. Scharrer',
#   'chair_affiliation': 'U of Massachusetts - Amherst',
#   'division': 'Children Adolescents and Media',
#   'years': [2014],
#   'paper_count': 8},
#  {'session': 'Aging and Health Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Hui Zhang',
#   'chair_affiliation': 'Colorado State U',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Alcohol Use Among College Students',
#   'session_type': 'Paper Session',
#   'chair_name': 'Saar Mollen',
#   'chair_affiliation': 'University of Amsterdam',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Alcohol, Diet, Behavior Change: High-Density Panel in Public Health Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Elisabeth Bigsby',
#   'chair_affiliation': 'U of Illinois',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 7},
#  {'session': 'Alternative Media and Counter Narratives',
#   'session_type': 'Paper Session',
#   'chair_name': 'Guobin Yang',
#   'chair_affiliation': 'U of Pennsylvania',
#   'division': 'Activism, Communication & Social Justice',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Always There When I Need You!: Providing Social Support in Close Relationships',
#   'session_type': 'Paper Session',
#   'chair_name': 'Lucas Youngvorst',
#   'chair_affiliation': 'University of Minnesota - Twin Cities',
#   'division': 'Interpersonal Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'An Examination of Instructional Communication Across Cultures',
#   'session_type': 'Paper Session',
#   'chair_name': 'Ryan Goke',
#   'chair_affiliation': 'Murray State U',
#   'division': 'Instructional & Developmental Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'An Examination of Sports Consumption and Fandom',
#   'session_type': 'Paper Session',
#   'chair_name': 'Erin Ash',
#   'chair_affiliation': 'Clemson University',
#   'division': 'Sports Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Analyses of Advertising Cues',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Kevin Wise',
#   'chair_affiliation': 'U of Illinois',
#   'division': 'Information Systems',
#   'years': [2014],
#   'paper_count': 8},
#  {'session': 'Analyses of Content and Structural Features of Messages',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Robert F. Potter',
#   'chair_affiliation': 'Indiana University',
#   'division': 'Information Systems',
#   'years': [2014],
#   'paper_count': 8},
#  {'session': 'Analyses of Gaming, Mobile Devices, and Technology',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Kristine L. Nowak',
#   'chair_affiliation': 'U of Connecticut',
#   'division': 'Information Systems',
#   'years': [2014],
#   'paper_count': 8},
#  {'session': 'Analyses of News Coverage: Cases and Patterns',
#   'session_type': 'Paper Session',
#   'chair_name': 'Michael Bruggeman',
#   'chair_affiliation': 'U Zürich',
#   'division': 'Journalism Studies',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Analyses of Stereotypes, Gender Roles, and Expectancy Violations in Media',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Michael David Hazen',
#   'chair_affiliation': 'Wake Forest U',
#   'division': 'Information Systems',
#   'years': [2014],
#   'paper_count': 8},
#  {'session': 'Anayzing Rhetoric: From George Bush to the Muslim Brotherhood',
#   'session_type': 'Paper Session',
#   'chair_name': 'Janice Barrett',
#   'chair_affiliation': 'Lasell College',
#   'division': 'Political Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Antecedent and Consequent Negative Psychological Profiles in Social Media Use',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nancy Tobler',
#   'chair_affiliation': 'Utah Valley U',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Anti-Smoking Messages and Campaigns',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nadine Bol',
#   'chair_affiliation': 'ASCoR',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Anti-Smoking PSAs, Web and Peer Influences',
#   'session_type': 'Paper Session',
#   'chair_name': 'Stanislav Orlov',
#   'chair_affiliation': 'Mount Saint Vincent University',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Anti-Social Scientists, on Some Dark-Side Topics',
#   'session_type': 'Paper Session',
#   'chair_name': 'Daniel Possler',
#   'chair_affiliation': 'Hannover U of Music',
#   'division': 'Game Studies',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Antialcohol Messages',
#   'session_type': 'Paper Session',
#   'chair_name': 'Emily Brennan',
#   'chair_affiliation': 'Cancer Council Victoria',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Antidrinking/Antialcohol Health Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Riina Raudne',
#   'chair_affiliation': 'Health Estonia Foundation',
#   'division': 'Health Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Antismoking Health Messages',
#   'session_type': 'Paper Session',
#   'chair_name': 'Bas van den Putte',
#   'chair_affiliation': 'U of Amsterdam',
#   'division': 'Health Communication',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Antismoking Health Messages and News',
#   'session_type': 'Paper Session',
#   'chair_name': 'Simon Zebregs',
#   'chair_affiliation': 'University of Amsterdam',
#   'division': 'Health Communication',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Antismoking/Antidrinking: High Density Panel in Health Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Elisabeth Bigsby',
#   'chair_affiliation': 'University of Illinois',
#   'division': 'Health Communication',
#   'years': [2016],
#   'paper_count': 7},
#  {'session': 'Appeals to Young People Through Advertising and Programming',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Children Adolescents and Media',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Applications of Health Behavior Change Theory',
#   'session_type': 'Paper Session',
#   'chair_name': 'Leanne Chang',
#   'chair_affiliation': 'National U - Singapore',
#   'division': 'Health Communication',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Are They Buying It? Consumer Socialization and Advertising Responses Among Children & Teens (HHD Session)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Mariska Kleemans',
#   'chair_affiliation': 'Radboud U Nijmegen',
#   'division': 'Children Adolescents and the Media',
#   'years': [2017],
#   'paper_count': 9},
#  {'session': 'Argument, Engagement, and Persuasion',
#   'session_type': 'Paper Session',
#   'chair_name': 'Marc Ziegele',
#   'chair_affiliation': 'Johannes Gutenberg University of Mainz',
#   'division': 'Mass Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Arguments, Argumentation, and Language Competence',
#   'session_type': 'Paper Session',
#   'chair_name': 'Ee Lin Lee',
#   'chair_affiliation': 'Western Washington U',
#   'division': 'Intercultural Communication',
#   'years': [2016],
#   'paper_count': 6},
#  {'session': 'As Good as Gold: Top 4 Papers in Organizational Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Craig R. Scott',
#   'chair_affiliation': 'Rutgers U',
#   'division': 'Organizational Communication',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'As Good as New: Emerging Paradigms/Directions in Organizational Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'R. Tyler Spradley',
#   'chair_affiliation': 'Stephen F. Austin State U',
#   'division': 'Organizational Communication',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Asian and Asian American Concerns',
#   'session_type': 'Paper Session',
#   'chair_name': 'Shinsuke Eguchi',
#   'chair_affiliation': 'University of New Mexico',
#   'division': 'Ethnicity and Race in Communication',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Assessing Internet Access: Content, Connection, and Speed',
#   'session_type': 'Paper Session',
#   'chair_name': 'Seamus Simpson',
#   'chair_affiliation': 'U of Salford',
#   'division': 'Communication Law & Policy',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Attention and Diffusion Processes',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Computational Methods',
#   'years': [2018],
#   'paper_count': 7},
#  {'session': 'Attention and Divided Attention',
#   'session_type': 'Paper Session',
#   'chair_name': 'Byungho Park',
#   'chair_affiliation': 'KAIST',
#   'division': 'Information Systems',
#   'years': [2017, 2016],
#   'paper_count': 16},
#  {'session': 'Attention, Cognition, and Embodiment',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Kristine L. Nowak',
#   'chair_affiliation': 'University of Connecticut',
#   'division': 'Information Systems',
#   'years': [2015],
#   'paper_count': 8},
#  {'session': 'Attitudes, Emotions, and Gratifications: A Psychological Perspective of Sports Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Paul Haridakis',
#   'chair_affiliation': 'Kent State U',
#   'division': 'Sports Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Audience Analysis in the Media Industries',
#   'session_type': 'Paper Session',
#   'chair_name': 'Patricia Frances Phalen',
#   'chair_affiliation': 'George Washington U',
#   'division': 'Media Industry Studies',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Audience Connections to Characters',
#   'session_type': 'Paper Session',
#   'chair_name': 'Kekeli Kwabla Nuviadenu',
#   'chair_affiliation': 'Bethune-Cookman U',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Audience Engagement With News (TOP FACULTY PAPER AWARDEE)',
#   'session_type': 'Paper Session',
#   'chair_name': 'David D. Perlmutter',
#   'chair_affiliation': 'Texas Tech University',
#   'division': 'Mass Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Audience Perceptions of Media Sources and Political Interest',
#   'session_type': 'Paper Session',
#   'chair_name': 'Lance Holbert',
#   'chair_affiliation': 'Temple U',
#   'division': 'Mass Communication',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Audience and Advertising in Social Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Maya Mazor',
#   'chair_affiliation': 'University of Haifa',
#   'division': 'Mass Communication',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Audiences and Fans: From Disney Fans to the Nursing Home',
#   'session_type': 'Paper Session',
#   'chair_name': 'Melissa A. Click',
#   'chair_affiliation': 'U of Missouri - Columbia',
#   'division': 'Popular Communication',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Authenticity and Iconicity Across Visual Media Genres',
#   'session_type': 'Paper Session',
#   'chair_name': 'Mary Angela Bock',
#   'chair_affiliation': 'U of Texas - Austin',
#   'division': 'Visual Communication Studies',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'B.E.S.T. Session: Emotions and Relationships in Organizational Contexts',
#   'session_type': 'Paper Session',
#   'chair_name': 'Elizabeth D. Wilhoit',
#   'chair_affiliation': 'Auburn U',
#   'division': 'Organizational Communication',
#   'years': [2018],
#   'paper_count': 9},
#  {'session': 'B.E.S.T. Session: Knowledge, Innovation, and Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'William C. Barley',
#   'chair_affiliation': 'U of Illinois',
#   'division': 'Organizational Communication',
#   'years': [2018],
#   'paper_count': 9},
#  {'session': 'B.E.S.T. Session: Teams, Change, Health, and Organizing',
#   'session_type': 'Paper Session',
#   'chair_name': 'Rebecca Gill',
#   'chair_affiliation': 'Wake Forest University',
#   'division': 'Organizational Communication',
#   'years': [2018],
#   'paper_count': 9},
#  {'session': 'B.E.S.T.: Activism, Volunteerism and Nongovernmental Organizations',
#   'session_type': 'Paper Session',
#   'chair_name': 'William C. Barley',
#   'chair_affiliation': 'U of Illinois',
#   'division': 'Organizational Communication',
#   'years': [2017],
#   'paper_count': 9},
#  {'session': 'B.E.S.T.: Communication Networks in and Between Organizations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Craig R. Scott',
#   'chair_affiliation': 'Rutgers U',
#   'division': 'Organizational Communication',
#   'years': [2015],
#   'paper_count': 9},
#  {'session': 'B.E.S.T.: Leadership, Managers, and Employees',
#   'session_type': 'Paper Session',
#   'chair_name': 'Jeffrey William Treem',
#   'chair_affiliation': 'U of Texas - Austin',
#   'division': 'Organizational Communication',
#   'years': [2017],
#   'paper_count': 9},
#  {'session': 'B.E.S.T.: Materiality and the Communicative Constitution of Organizations',
#   'session_type': 'Paper Session',
#   'chair_name': 'R. Tyler Spradley',
#   'chair_affiliation': 'Stephen F. Austin State U',
#   'division': 'Organizational Communication',
#   'years': [2017],
#   'paper_count': 9},
#  {'session': 'B.E.S.T.: Networks and Social Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Bart J. van den Hooff',
#   'chair_affiliation': 'U of Amsterdam',
#   'division': 'Organizational Communication',
#   'years': [2017],
#   'paper_count': 9},
#  {'session': 'B.E.S.T.: Organizations, Communication, and Technology',
#   'session_type': 'Paper Session',
#   'chair_name': 'Craig R. Scott',
#   'chair_affiliation': 'Rutgers U',
#   'division': 'Organizational Communication',
#   'years': [2015],
#   'paper_count': 9},
#  {'session': 'B.E.S.T.: Social Responsibility and Ethics in Communication Practice and Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Craig R. Scott',
#   'chair_affiliation': 'Rutgers U',
#   'division': 'Organizational Communication',
#   'years': [2016],
#   'paper_count': 7},
#  {'session': 'B.E.S.T.: Social and Collaborative Technologies in Organizational Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Bart J. van den Hooff',
#   'chair_affiliation': 'VU University Amsterdam',
#   'division': 'Organizational Communication',
#   'years': [2016],
#   'paper_count': 8},
#  {'session': 'B.E.S.T.: The Dark Side of Organizations--Paranoia/Paradox, Risk/Disaster, Invisibility, Unemployment, Ostracizing and Beyond...',
#   'session_type': 'Paper Session',
#   'chair_name': 'Craig R. Scott',
#   'chair_affiliation': 'Rutgers U',
#   'division': 'Organizational Communication',
#   'years': [2015],
#   'paper_count': 9},
#  {'session': 'Balance and Bias in News Exposure',
#   'session_type': 'Paper Session',
#   'chair_name': 'Patricia Moy',
#   'chair_affiliation': 'U of Washington',
#   'division': 'Political Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Behavioral Dynamics in Online Communities',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Computational Methods',
#   'years': [2018],
#   'paper_count': 7},
#  {'session': 'Behavioral and Perceptual Outcomes of Social Media Use',
#   'session_type': 'Paper Session',
#   'chair_name': 'Anne Oeldorf-Hirsch',
#   'chair_affiliation': 'University of Connecticut',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Best Faculty Papers in Public Relations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Chiara Valentini',
#   'chair_affiliation': 'Aarhus U',
#   'division': 'Public Relations',
#   'years': [2014, 2015],
#   'paper_count': 10},
#  {'session': 'Best Paper Awards Game Studies Division',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nicholas David Bowman',
#   'chair_affiliation': 'West Virginia U',
#   'division': 'Game Studies',
#   'years': [2017],
#   'paper_count': 3},
#  {'session': 'Best Papers in Game Studies Division',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nicholas David Bowman',
#   'chair_affiliation': 'West Virginia U',
#   'division': 'Game Studies',
#   'years': [2016],
#   'paper_count': 3},
#  {'session': 'Best Papers in Information Systems Division',
#   'session_type': 'Paper Session',
#   'chair_name': 'Kevin Wise',
#   'chair_affiliation': 'U of Illinois',
#   'division': 'Information Systems',
#   'years': [2016, 2017],
#   'paper_count': 8},
#  {'session': 'Best Student Papers in Public Relations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Chiara Valentini',
#   'chair_affiliation': 'Aarhus U',
#   'division': 'Public Relations',
#   'years': [2014, 2015],
#   'paper_count': 10},
#  {'session': 'Best of Information Systems',
#   'session_type': 'Paper Session',
#   'chair_name': 'Prabu David',
#   'chair_affiliation': 'Washington State U',
#   'division': 'Information Systems',
#   'years': [2014, 2015, 2018],
#   'paper_count': 12},
#  {'session': 'Between Partisan Media and Partisan Opinions',
#   'session_type': 'Paper Session',
#   'chair_name': 'Eike Mark Rinke',
#   'chair_affiliation': 'U of Mannheim',
#   'division': 'Political Communication',
#   'years': [2016],
#   'paper_count': 3},
#  {'session': 'Between Propaganda and Government Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Shannon C McGregor',
#   'chair_affiliation': 'University of Texas at Austin',
#   'division': 'Political Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Between Science and the Public: Studies in Science Journalism',
#   'session_type': 'Paper Session',
#   'chair_name': 'Henrik Ornebring',
#   'chair_affiliation': 'Karlstad U',
#   'division': 'Journalism Studies',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Beyond Churnalism',
#   'session_type': 'Paper Session',
#   'chair_name': 'Omar Al-Ghazzi',
#   'chair_affiliation': 'London School of Economics and Political Science (LSE)',
#   'division': 'Journalism Studies',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Beyond Lora: Female Gender in Games',
#   'session_type': 'Paper Session',
#   'chair_name': 'Andre Melzer',
#   'chair_affiliation': 'University of Luxembourg',
#   'division': 'Game Studies',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Bias, Cues, Judgment and Decision Making',
#   'session_type': 'Paper Session',
#   'chair_name': 'Alyssa C Morey',
#   'chair_affiliation': 'U at Albany',
#   'division': 'Information Systems',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'Bias, Intentionality, Judgment, and Decision Making',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Nancy Rhodes',
#   'chair_affiliation': 'Michigan State University',
#   'division': 'Information Systems',
#   'years': [2016],
#   'paper_count': 8},
#  {'session': 'Big Data & Networks: Connecting Communities, Organizations, and Reviews',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Big Data and Algorithms: Theory and Critique',
#   'session_type': 'Paper Session',
#   'chair_name': 'Jayson Harsin',
#   'chair_affiliation': 'The American U of Paris',
#   'division': 'Philosophy, Theory and Critique',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Bodies in Place: Mediated Identities and Intersections',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Popular Communication',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Body Image, Idealized Image, and Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Liese Exelmans',
#   'chair_affiliation': 'U of Leuven - School for Mass Communication Research',
#   'division': 'Mass Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Border and Refugee Intercultural Experiences/Dynamics',
#   'session_type': 'Paper Session',
#   'chair_name': 'Juana Juan Du',
#   'chair_affiliation': 'Royal Roads University',
#   'division': 'Intercultural Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Boundaries: Questioning the Local, Global, and Transnational',
#   'session_type': 'Paper Session',
#   'chair_name': 'Terry Flew',
#   'chair_affiliation': 'Queensland U of Technology',
#   'division': 'Media Industry Studies',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': "Building Brands: Deconstructing Media Institutions' Constructions and Omissions",
#   'session_type': 'Paper Session',
#   'chair_name': 'Matthew P. McAllister',
#   'chair_affiliation': 'Pennsylvania State U',
#   'division': 'Popular Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Building the Pacific Research Platform: Supernetworks for Big Data Science (Steve Jones Internet Lecture)',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Sponsored Sessions'},
#  {'session': 'Business Models and Business Strategies in Journalism and Television',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Media Industry Studies',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'CAM Research Escalator Session 1',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Children Adolescents and the Media',
#   'years': [2016],
#   'paper_count': 7},
#  {'session': 'CAM Research Escalator Session 2',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Children Adolescents and the Media',
#   'years': [2016],
#   'paper_count': 8},
#  {'session': 'CAT Hybrid Session 1: ICTs, Divides, and Privacy',
#   'session_type': 'Paper Session',
#   'chair_name': 'Lee Humphreys',
#   'chair_affiliation': 'Cornell University',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'CAT Hybrid Session 2: Virtual Experiences and Interaction',
#   'session_type': 'Paper Session',
#   'chair_name': 'Elizabeth Newbury',
#   'chair_affiliation': 'Cornell U',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 8},
#  {'session': 'CAT Hybrid Session 3: Social Media, Interactions, and Self-Presentation',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nicole Ellison',
#   'chair_affiliation': 'School of Information',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 8},
#  {'session': 'CAT Hybrid Session 4: Collaboration, Work, and Organizations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Drew Berkley Margolin',
#   'chair_affiliation': 'Cornell University',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 7},
#  {'session': 'CAT Hybrid Session 5: Global Perspectives on Technology',
#   'session_type': 'Paper Session',
#   'chair_name': 'Katy Elizabeth Pearce',
#   'chair_affiliation': 'U of Washington',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 7},
#  {'session': 'CAT Interactive Paper Session 1',
#   'session_type': 'Paper Session',
#   'chair_name': 'Aubrie Serena Adams',
#   'chair_affiliation': 'California Polytechnic State U',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 6},
#  {'session': 'CAT Interactive Paper Session 2',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nia Sarinastiti',
#   'chair_affiliation': 'Atma Jaya Catholic University of Indonesia',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'CAT Interactive Paper Session 3',
#   'session_type': 'Paper Session',
#   'chair_name': 'Mike Z. Yao',
#   'chair_affiliation': 'U of Illinois at Urbana-Champaign',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 7},
#  {'session': 'CAT Interactive Paper Session 4',
#   'session_type': 'Paper Session',
#   'chair_name': 'Chih-Hui Lai',
#   'chair_affiliation': 'National Chiao Tung U',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'CAT Interactive Paper Session 5',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Daniel Angus',
#   'chair_affiliation': 'University of Queensland',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'CAT Interactive Paper Session 6',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Benjamin K. Johnson',
#   'chair_affiliation': 'Vrije U Amsterdam',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'CAT Interactive Papers #1',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Peng Hwa Ang',
#   'chair_affiliation': 'Nanyang Technological U',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 6},
#  {'session': 'CAT Interactive Papers #2',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Leah A. Lievrouw',
#   'chair_affiliation': 'U of California - Los Angeles',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 6},
#  {'session': 'CAT Interactive Papers #3',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Marjolijn L. Antheunis',
#   'chair_affiliation': 'Tilburg University',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 8},
#  {'session': 'CAT Interactive Papers #4',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Lee Humphreys',
#   'chair_affiliation': 'Cornell University',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 7},
#  {'session': 'CCA & KACA Joint Paper Session: Health and Safety: Emotion, Learning, and Behavior From the Media',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Sponsored Sessions'},
#  {'session': 'CLAP Conference Theme Session: Communication Law and Policy Issues Across the Life Span',
#   'session_type': 'Paper Session',
#   'chair_name': 'Seamus Simpson',
#   'chair_affiliation': 'U of Salford',
#   'division': 'Communication Law & Policy',
#   'years': [2015],
#   'paper_count': 6},
#  {'session': 'CSR, Communication, and Public Perceptions',
#   'session_type': 'Paper Session',
#   'chair_name': 'Anne Ellerup Nielsen',
#   'chair_affiliation': 'BSS - Aarhus University',
#   'division': 'Public Relations',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'CSR: Interventions in Research and Practice (High-Density)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Shannon Bowen',
#   'chair_affiliation': 'U of South Carolina',
#   'division': 'Public Relations',
#   'years': [2017],
#   'paper_count': 10},
#  {'session': 'Campaign Strategies and Information Effects: Insights From Europe',
#   'session_type': 'Paper Session',
#   'chair_name': 'Frank Esser',
#   'chair_affiliation': 'U of Zurich',
#   'division': 'Political Communication',
#   'years': [2017],
#   'paper_count': 3},
#  {'session': 'Cancer Health Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Rebekah Nagler',
#   'chair_affiliation': 'U of Minnesota',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Capturing Sight and Sound: Histories of Documentation',
#   'session_type': 'Paper Session',
#   'chair_name': 'Travers Scott',
#   'chair_affiliation': 'Clemson U',
#   'division': 'Communication History',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Censorship & Self Censorship in Authoritarian and Authoritarian Leaning States',
#   'session_type': 'Paper Session',
#   'chair_name': 'Patricia Moy',
#   'chair_affiliation': 'U of Washington',
#   'division': 'Political Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Challenges in Content Regulation',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Communication Law & Policy',
#   'years': [2017],
#   'paper_count': 6},
#  {'session': 'Challenges to Effective Communication in Healthcare Settings',
#   'session_type': 'Paper Session',
#   'chair_name': 'Yulia Strekalova',
#   'chair_affiliation': 'U of Florida',
#   'division': 'Health Communication',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Challenges to Effective Health Communication in Clinical Settings',
#   'session_type': 'Paper Session',
#   'chair_name': 'Carma Bylund',
#   'chair_affiliation': '1973',
#   'division': 'Health Communication',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Challenging Expectations in Journalism Studies Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Folker Christian Hanusch',
#   'chair_affiliation': 'Queensland U of Technology',
#   'division': 'Journalism Studies',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Change Has Come? Media and Popular Culture Reimaginings, Makeovers, and Transformations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nicholas A. John',
#   'chair_affiliation': 'The Hebrew University of Jerusalem',
#   'division': 'Popular Communication',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Changes in Broadcasting and News Systems',
#   'session_type': 'Paper Session',
#   'chair_name': 'Suda Ishida',
#   'chair_affiliation': 'Hamline U',
#   'division': 'Global Communication and Social Change',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Changing Audiovisual Media Markets and Regulation',
#   'session_type': 'Paper Session',
#   'chair_name': 'Rita Zajacz',
#   'chair_affiliation': 'U of Iowa',
#   'division': 'Communication Law & Policy',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': "Changing the News 140 Characters At a Time: Twitter's Impact on Journalism",
#   'session_type': 'Paper Session',
#   'chair_name': 'Seth C. Lewis',
#   'chair_affiliation': 'U of Minnesota',
#   'division': 'Journalism Studies',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Check It Out: Fact Checking on Old and New Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Drew Berkley Margolin',
#   'chair_affiliation': 'Cornell University',
#   'division': 'Political Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Children & Family Health Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Ashley P. Duggan',
#   'chair_affiliation': 'Boston College',
#   'division': 'Health Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Children, Adolescence, and Parental Mediation',
#   'session_type': 'Paper Session',
#   'chair_name': 'Kimberly Bissell',
#   'chair_affiliation': 'U of Alabama',
#   'division': 'Mass Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Children, Adolescents and the Media Interactive Poster Session',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'In Event: ICA Interactive Paper/Poster Session I',
#   'years': [2018],
#   'paper_count': 8},
#  {'session': 'Children, Adolescents and the Media Research Escalator Session',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nancy Jennings',
#   'chair_affiliation': 'U of Cincinnati',
#   'division': 'Children Adolescents and the Media',
#   'years': [2018],
#   'paper_count': 15},
#  {'session': 'Children, Adolescents, & the Media Division - Research Escalator Sessions (Panel 1)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sahara Byrne',
#   'chair_affiliation': 'Cornell U',
#   'division': 'Children Adolescents and the Media',
#   'years': [2017],
#   'paper_count': 12},
#  {'session': 'Children, Adolescents, & the Media Division - Research Escalator Sessions (Panel 2)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sahara Byrne',
#   'chair_affiliation': 'Cornell U',
#   'division': 'Children Adolescents and the Media',
#   'years': [2017],
#   'paper_count': 11},
#  {'session': 'Children, Adolescents, & the Media Interactive Poster Session',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'In Event: ICA Interactive paper/Poster Session I',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'Children, Adolescents, and Media: Research Escalator 1',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sahara Byrne',
#   'chair_affiliation': 'Cornell U',
#   'division': 'Children Adolescents and the Media',
#   'years': [2015],
#   'paper_count': 9},
#  {'session': 'Children, Adolescents, and Media: Research Escalator 2',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sahara Byrne',
#   'chair_affiliation': 'Cornell U',
#   'division': 'Children Adolescents and the Media',
#   'years': [2015],
#   'paper_count': 10},
#  {'session': 'Children, Adolescents, and the Media Interactive Poster Session',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'In Event: ICA Plenary Interactive Paper/Poster Session and Reception',
#   'years': [2013, 2014, 2015, 2016],
#   'paper_count': 29},
#  {'session': 'Citizens and the News: Participants, Sources, Journalists?',
#   'session_type': 'Paper Session',
#   'chair_name': 'Helle Sjovaag',
#   'chair_affiliation': 'University of Bergen',
#   'division': 'Journalism Studies',
#   'years': [2015],
#   'paper_count': 5},
#  {'session': 'Citizens as Collaborators: Extending the Voices of Journalism',
#   'session_type': 'Paper Session',
#   'chair_name': 'Mark Anthony Poepsel',
#   'chair_affiliation': 'Southern Illinois U Edwardsville',
#   'division': 'Journalism Studies',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': "Citizens' Voices in Policy: Rights, Protection, Expectations",
#   'session_type': 'Paper Session',
#   'chair_name': 'Katharine Sarikakis',
#   'chair_affiliation': 'U of Vienna',
#   'division': 'Communication Law & Policy',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Citizenship, Community, and Civic Engagement',
#   'session_type': 'Paper Session',
#   'chair_name': 'Karolina Koc-Michalska',
#   'chair_affiliation': 'Audencia Business School',
#   'division': 'Political Communication',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Civic Engagement With Social Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nicole C. Kramer',
#   'chair_affiliation': 'U of Duisburg-Essen',
#   'division': 'Communication and Technology',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Civic Tech and the Politics of Technology',
#   'session_type': 'Paper Session',
#   'chair_name': 'Lina Dencik',
#   'chair_affiliation': 'Cardciff U',
#   'division': 'Activism, Communication & Social Justice',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Clarifying and Advancing Theory in Mass Communication Research (TOP PAPER ENTRY)',
#   'session_type': 'Paper Session',
#   'chair_name': 'Erica L. Scharrer',
#   'chair_affiliation': 'U of Massachusetts - Amherst',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Climate Change Communication',
#   'session_type': 'Paper Session',
# ...
#   'paper_count': 4},
#  {'session': 'Methodological and Theoretical Advances',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'James M. Honeycutt',
#   'chair_affiliation': 'Louisiana State University',
#   'division': 'Information Systems',
#   'years': [2015],
#   'paper_count': 8},
#  {'session': 'Methodological and Theoretical Advances in Understanding the Relationship Between Social Media Use and Mental Health',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sabine Trepte',
#   'chair_affiliation': 'U of Hohenheim',
#   'division': 'Communication and Technology',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Methodology: New Thinking About Methods and Measures',
#   'session_type': 'Paper Session',
#   'chair_name': 'Josef Seethaler',
#   'chair_affiliation': 'Austrian Academy of Sciences',
#   'division': 'Political Communication',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Middle East and North African (MENA) Media and Public Communications After the "Arab Spring"',
#   'session_type': 'Paper Session',
#   'chair_name': 'Joe F. Khalil',
#   'chair_affiliation': 'Northwestern U -Qatar',
#   'division': 'Global Communication and Social Change',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Migration, Minorities, and Diasporas',
#   'session_type': 'Paper Session',
#   'chair_name': 'LeiLani Nishime',
#   'chair_affiliation': 'U of Washington',
#   'division': 'Ethnicity and Race in Communication',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Misinformation and Correction',
#   'session_type': 'Paper Session',
#   'chair_name': 'Jonathan Cohen',
#   'chair_affiliation': 'U of Haifa',
#   'division': 'Mass Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Mobile Access and Privacy',
#   'session_type': 'Paper Session',
#   'chair_name': 'Leah Jerop KOMEN',
#   'chair_affiliation': 'Daystar U',
#   'division': 'Mobile Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Mobile Adoption and Use',
#   'session_type': 'Paper Session',
#   'chair_name': 'Chenta Sung',
#   'chair_affiliation': 'London School of Economics and Political Science',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Mobile Apps and Narratives',
#   'session_type': 'Paper Session',
#   'chair_name': 'Nathaniel D. Poor',
#   'chair_affiliation': 'Underwood Institute',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Mobile Communication Interactive Poster Session',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'In Event: ICA Plenary Interactive Paper/Poster Session I',
#   'years': [2016, 2017, 2018],
#   'paper_count': 11},
#  {'session': 'Mobile Communication Theory',
#   'session_type': 'Paper Session',
#   'chair_name': 'Colin Agur',
#   'chair_affiliation': 'U of Minnesota',
#   'division': 'Mobile Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Mobile Communication Top Papers',
#   'session_type': 'Paper Session',
#   'chair_name': 'Jason A. Martin',
#   'chair_affiliation': 'DePaul U',
#   'division': 'Mobile Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Mobile Communication and Organizations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Colin Agur',
#   'chair_affiliation': 'U of Minnesota',
#   'division': 'Mobile Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Mobile Compared to Immobile Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Colin Agur',
#   'chair_affiliation': 'Yale University',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Mobile Health',
#   'session_type': 'Paper Session',
#   'chair_name': 'Colin Agur',
#   'chair_affiliation': 'U of Minnesota',
#   'division': 'Mobile Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Mobile Health Communication: Health Apps, Activity Tracking, Texting, Online',
#   'session_type': 'Paper Session',
#   'chair_name': 'Qinghua Yang',
#   'chair_affiliation': 'University of Pennsylvania',
#   'division': 'Health Communication',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Mobile Innovation and Advertising',
#   'session_type': 'Paper Session',
#   'chair_name': 'Veronika Karnowski',
#   'chair_affiliation': 'LMU Munich',
#   'division': 'Mobile Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Mobile Media, Digital Media, and Youth',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Children Adolescents and Media',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Mobile Motivations',
#   'session_type': 'Paper Session',
#   'chair_name': 'Veronika Karnowski',
#   'chair_affiliation': 'Ludwig Maximilians U Munich',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Mobile Phones and Consumer Behaviors',
#   'session_type': 'Paper Session',
#   'chair_name': 'Trisha T. C. Lin',
#   'chair_affiliation': 'Nanyang Technological U',
#   'division': 'Communication and Technology',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Mobile Phones and Macro to Micro Behaviors',
#   'session_type': 'Paper Session',
#   'chair_name': 'Brett Oppegaard',
#   'chair_affiliation': 'Washington State U- Vancouver',
#   'division': 'Communication and Technology',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Mobile Phones and Social Behaviors',
#   'session_type': 'Paper Session',
#   'chair_name': 'Ronald A Yaros',
#   'chair_affiliation': 'U of Maryland',
#   'division': 'Communication and Technology',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Mobile Social Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Rich Ling',
#   'chair_affiliation': 'Nanyang Technological University/Telenor',
#   'division': 'Mobile Communication',
#   'years': [2016, 2018],
#   'paper_count': 8},
#  {'session': 'Mobile and Online Health Interventions',
#   'session_type': 'Paper Session',
#   'chair_name': 'Gi Woong Yun',
#   'chair_affiliation': 'U of Nevada',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Mobility and Migration',
#   'session_type': 'Paper Session',
#   'chair_name': 'Colin Agur',
#   'chair_affiliation': 'U of Minnesota',
#   'division': 'Mobile Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Models, Tools, and Methods for Visual Communication Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Laurie Gries',
#   'chair_affiliation': 'University of Colorado',
#   'division': 'Visual Communication Studies',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Modern Visual Cultures',
#   'session_type': 'Paper Session',
#   'chair_name': 'David W. Park',
#   'chair_affiliation': 'Lake Forest College',
#   'division': 'Communication History',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Moral and Legal Dilemmas in Communication Law and Policy',
#   'session_type': 'Paper Session',
#   'chair_name': 'Hilde Dy Van den Bulck',
#   'chair_affiliation': 'U of Antwerp',
#   'division': 'Communication Law & Policy',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Morals and Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sonny Rosenthal',
#   'chair_affiliation': 'Nanyang Technological University',
#   'division': 'Mass Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Motivated Cognition and Behavior',
#   'session_type': 'Paper Session',
#   'chair_name': 'Yongkuk Chung',
#   'chair_affiliation': 'Dongguk U',
#   'division': 'Information Systems',
#   'years': [2017, 2016],
#   'paper_count': 16},
#  {'session': 'Motivation',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Josephine Schmitt',
#   'chair_affiliation': 'University of Hohenheim',
#   'division': 'Information Systems',
#   'years': [2015],
#   'paper_count': 8},
#  {'session': 'Motivations for Technology Adoption and Use',
#   'session_type': 'Paper Session',
#   'chair_name': 'Weiyu Zhang',
#   'chair_affiliation': 'National U of Singapore',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Moving Us Forward: Pushing Our Theoretical and Methodological Boundaries',
#   'session_type': 'Paper Session',
#   'chair_name': 'Anne Marthe Möller',
#   'chair_affiliation': 'U of Amsterdam',
#   'division': 'Children Adolescents and the Media',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Multitasking With Technology',
#   'session_type': 'Paper Session',
#   'chair_name': 'Margaret Elizabeth Young',
#   'chair_affiliation': 'UW Information School',
#   'division': 'Communication and Technology',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Multitasking and Attention',
#   'session_type': 'Paper Session',
#   'chair_name': 'Benjamin K. Johnson',
#   'chair_affiliation': 'Vrije U Amsterdam',
#   'division': 'Communication and Technology',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Multitasking and Selective Attention',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Zheng Joyce Wang',
#   'chair_affiliation': 'The Ohio State University',
#   'division': 'Information Systems',
#   'years': [2015],
#   'paper_count': 8},
#  {'session': 'Music, Sound, and Popular Culture',
#   'session_type': 'Paper Session',
#   'chair_name': 'Lillian Boxman-Shabtai',
#   'chair_affiliation': 'Northwestern University',
#   'division': 'Popular Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'My Other Self: Presence and Identity in Games',
#   'session_type': 'Paper Session',
#   'chair_name': 'Changhyun Ahn',
#   'chair_affiliation': 'U at Buffalo',
#   'division': 'Game Studies',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Narrations of Rape in Postcolonial India and Beyond: Rape Discourse in Global Contests of Power',
#   'session_type': 'Paper Session',
#   'chair_name': 'Angharad N. Valdivia',
#   'chair_affiliation': 'U of Illinois',
#   'division': 'Feminist Scholarship',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Narrative Engagement and Persuasion',
#   'session_type': 'Paper Session',
#   'chair_name': 'Rick W. Busselle',
#   'chair_affiliation': 'Bowling Green State University',
#   'division': 'Mass Communication',
#   'years': [2014],
#   'paper_count': 5},
#  {'session': 'Narrative Involvement and Persuasion',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sonya Dal Cin',
#   'chair_affiliation': 'U of Michigan',
#   'division': 'Mass Communication',
#   'years': [2017],
#   'paper_count': 4},
#  {'session': 'Narrative Motifs of Gendered Stereotypes, Health, Cigarettes, and Other Entertainments',
#   'session_type': 'Paper Session',
#   'chair_name': 'Catherine L. Preston',
#   'chair_affiliation': 'U of Kansas',
#   'division': 'Visual Communication Studies',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Narrative Persuasion Research',
#   'session_type': 'Paper Session',
#   'chair_name': 'Rick W. Busselle',
#   'chair_affiliation': 'Bowling Green State U',
#   'division': 'Mass Communication',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Narrative Persuasion in Health Contexts',
#   'session_type': 'Paper Session',
#   'chair_name': 'Tae Kyoung Lee',
#   'chair_affiliation': 'University of Utah',
#   'division': 'Health Communication',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Narrative Processes in Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Jonathan Cohen',
#   'chair_affiliation': 'U of Haifa',
#   'division': 'Mass Communication',
#   'years': [2013, 2014],
#   'paper_count': 9},
#  {'session': 'Narrative Processing',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Elizabeth L. Cohen',
#   'chair_affiliation': 'West Virginia University',
#   'division': 'Information Systems',
#   'years': [2016],
#   'paper_count': 8},
#  {'session': 'Narrative Processing I',
#   'session_type': 'Paper Session',
#   'chair_name': 'Michael D. Slater',
#   'chair_affiliation': 'The Ohio State U',
#   'division': 'Information Systems',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'Narrative Processing II',
#   'session_type': 'Paper Session',
#   'chair_name': 'Michael A. Shapiro',
#   'chair_affiliation': 'Cornell U',
#   'division': 'Information Systems',
#   'years': [2017],
#   'paper_count': 8},
#  {'session': 'Narrative and Media Entertainment',
#   'session_type': 'Interactive Paper Session',
#   'chair_name': 'Brandon Harley Nutting',
#   'chair_affiliation': 'U of South Dakota',
#   'division': 'Information Systems',
#   'years': [2015],
#   'paper_count': 8},
#  {'session': 'Narratives',
#   'session_type': 'Paper Session',
#   'chair_name': 'Michael W. Wagner',
#   'chair_affiliation': 'U of Wisconsin-Madison',
#   'division': 'Mass Communication',
#   'years': [2018],
#   'paper_count': 4},
#  {'session': 'Narratives, Self-Presentation, and Cheating: From Edutainment to Lying in the Classroom',
#   'session_type': 'Paper Session',
#   'chair_name': 'Marjorie Buckner',
#   'chair_affiliation': 'University of Kentucky',
#   'division': 'Instructional & Developmental Communication',
#   'years': [2014],
#   'paper_count': 3},
#  {'session': 'Nation, Narrative, and Histories of News',
#   'session_type': 'Paper Session',
#   'chair_name': 'Samantha Oliver',
#   'chair_affiliation': 'Annenberg School for Communication',
#   'division': 'Communication History',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'National and Organizational Culture and Communication',
#   'session_type': 'Paper Session',
#   'chair_name': 'Francois Cooren',
#   'chair_affiliation': 'U de Montreal',
#   'division': 'Organizational Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Native Advertising, Branded Content, and Audience Engagement',
#   'session_type': 'Paper Session',
#   'chair_name': 'Patricia Frances Phalen',
#   'chair_affiliation': 'George Washington U',
#   'division': 'Media Industry Studies',
#   'years': [2017],
#   'paper_count': 5},
#  {'session': 'Negative Campaigns and Campaign Negativity',
#   'session_type': 'Paper Session',
#   'chair_name': 'Christian Schemer',
#   'chair_affiliation': 'University of Mainz',
#   'division': 'Political Communication',
#   'years': [2016],
#   'paper_count': 4},
#  {'session': 'Negative Effects of Social Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Cornelius Puschmann',
#   'chair_affiliation': 'Alexander von Humboldt Institute for Internet and Society',
#   'division': 'Communication and Technology',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Negative Socioemotional Performances in Social Media',
#   'session_type': 'Paper Session',
#   'chair_name': 'Yeuseung Kim',
#   'chair_affiliation': 'DePaul University',
#   'division': 'Communication and Technology',
#   'years': [2015],
#   'paper_count': 4},
#  {'session': 'Negotiating Media Logics in Crisis Situations: Attention Management and Self-Protection Strategies',
#   'session_type': 'Paper Session',
#   'chair_name': 'Risto Kunelius',
#   'chair_affiliation': 'U of Tampere',
#   'division': 'Journalism Studies',
#   'years': [2018],
#   'paper_count': 5},
#  {'session': 'Negotiating New Tensions in News Production',
#   'session_type': 'Paper Session',
#   'chair_name': 'Juliette De Maeyer',
#   'chair_affiliation': 'U de Montral',
#   'division': 'Journalism Studies',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Negotiations and Portrayals of Motherhood in Media Discourses Around the World',
#   'session_type': 'Paper Session',
#   'chair_name': nan,
#   'chair_affiliation': nan,
#   'division': 'Feminist Scholarship',
#   'years': [2016],
#   'paper_count': 5},
#  {'session': 'Network Analyses of Online Message Content',
#   'session_type': 'Paper Session',
#   'chair_name': 'Porismita Borah',
#   'chair_affiliation': 'Washington State University',
#   'division': 'Communication and Technology',
#   'years': [2014],
#   'paper_count': 4},
#  {'session': 'Network Analysis',
#   'session_type': 'Paper Session',
#   'chair_name': 'Sandra Gonzalez-Bailon',
#   'chair_affiliation': 'U of Pennsylvania',
#   'division': 'Computational Methods',
#   'years': [2018],
#   'paper_count': 7},
#  ...]
