# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../data/processed/authors.csv')
df.head()
# Out:
#     Paper ID                                              Title  \
# 0  2003-0001  Access to the Media Versus Access to Audiences...
# 1  2003-0002  Accounting Episodes as Communicative Practice ...
# 2  2003-0003        Accounts of Single-fatherhood: A case study
# 3  2003-0003        Accounts of Single-fatherhood: A case study
# 4  2003-0003        Accounts of Single-fatherhood: A case study
#
#    Number of Authors  Author Position           Author Name  \
# 0                  1                1         Philip Napoli
# 1                  1                1         Mariko Kotani
# 2                  4                1  Tara M Emmers-Sommer
# 3                  4                2            David Rhea
# 4                  4                3        Laura Triplett
#
#          Author Affiliation  Year
# 0                 Fordham U  2003
# 1  Aoyama Gakuin University  2003
# 2     University of Arizona  2003
# 3     University of Arizona  2003
# 4     University of Arizona  2003

# %%
df[df['Author Affiliation'].isnull()]
# Out:
#         Paper ID                                              Title  \
# 57     2003-0031  A Meta-Analytical Review of the Relationship b...
# 65     2003-0036  A Multilevel Study of Interpersonal Influence ...
# 81     2003-0046  and the way its worded makes it
# : Discursiv...
# 88     2003-0050  A New Approach to U.S. Copyright Policy agains...
# 96     2003-0055  An Organizational Digital Divide: Web Adoption...
# ...          ...                                                ...
# 54110  2018-0149  Framing Effects and Algorithm-Based News Recom...
# 54221  2018-0200  ACT: An Evidence Based Macro Framework to Exam...
# 54237  2018-0210  Critical Analysis of Transmedia Storytelling o...
# 54263  2018-0225  With Their Own Voice: Inducing News Media Trus...
# 54283  2018-0238  Anti-Immigrationism on Twitter: Hegemonic Disc...
#
#        Number of Authors  Author Position           Author Name  \
# 57                     3                2  Lawrence R. Wheeless
# ...
