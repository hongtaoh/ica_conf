# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
import json 
import numpy as np

uri = "mongodb+srv://hhao9:ica_conf_data@cluster0.xi6gx.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

print(client.list_database_names())

db = client.ica_conf

print(db.list_collection_names())

papers_collection = db['papers']
authors_collection = db['authors']
sessions_collection = db['sessions']
# Out:
# ['carsApp', 'ica_conf', 'test', 'admin', 'local']
# ['authors', 'papers', 'sessions']

# %%
papers = pd.read_csv('../data/processed/paper_df.csv')
papers.sample()
# Out:
#         Paper ID                                              Title  \
# 22992  2017-0960  The Influence of American Idol Through Celebri...
#
#           Paper Type                                           Abstract  \
# 22992  Paper Session  The purpose of the present study is to explore...
#
#        Number of Authors  Year                     Session       Division/Unit
# 22992                4.0  2017  Media Parasocial Relations  Mass Communication

# %%
papers.shape
# Out:
# (27466, 8)

# %%
# convert to dicts
paper_records = papers.to_dict(orient='records')
paper_records[1:3]
# Out:
# [{'Paper ID': '2003-0002',
#   'Title': 'Accounting Episodes as Communicative Practice Affecting Cultural Knowledge',
#   'Paper Type': 'Paper',
#   'Abstract': "In this paper I describe accounting episodes as communicative practice that can affect participants' cultural knowledge in boundaries of speech communities. On the basis of in-depth interviews with Japanese-speaking informants in the United States, I analyze: (1) the episodes in which informants' cultural knowledge about appropriate conduct was affected or broadened by their engaging in accounting practices with American English speakers; and (2) the cases in which informants did not pursue the problematic events that they had faced with English speakers because, in reality, they saw difficulty in doing so. In the latter cases, informants' cultural knowledge and their perception of the boundaries tended to remain as they had been before the problematic events. The study supports the idea that boundaries of speech communities are dynamic but also suggests that they would not change so easily because participants often choose not to engage in accounting episodes.",
#   'Number of Authors': 1.0,
#   'Year': 2003,
#   'Session': nan,
#   'Division/Unit': nan},
#  {'Paper ID': '2003-0003',
#   'Title': 'Accounts of Single-fatherhood: A case study',
#   'Paper Type': 'Paper',
#   'Abstract': 'Abstract\nRelying on single-fathers\x92 accounts in a case-study approach, this study examined the experience of single-fatherhood and the communication practices between single-fathers and their child. Single-fathers also answered closed-ended questions. Results offer insight into the challenges and joys that single-fathers experience. Single-fathers clearly disclosed love for their child and a valuation of their relationship with their child, and expressed exasperation and dissatisfaction with the court system and negative perceptions of single-fathers by society. More detailed information and discussion follow.',
#   'Number of Authors': 4.0,
#   'Year': 2003,
#   'Session': nan,
#   'Division/Unit': nan}]

# %%
# papers_collection.insert_many(paper_records)
# Out:
# InsertManyResult([ObjectId('6720209c27ed2a37ccd59e30'), ObjectId('6720209c27ed2a37ccd59e31'), ObjectId('6720209c27ed2a37ccd59e32'), ObjectId('6720209c27ed2a37ccd59e33'), ObjectId('6720209c27ed2a37ccd59e34'), ObjectId('6720209c27ed2a37ccd59e35'), ObjectId('6720209c27ed2a37ccd59e36'), ObjectId('6720209c27ed2a37ccd59e37'), ObjectId('6720209c27ed2a37ccd59e38'), ObjectId('6720209c27ed2a37ccd59e39'), ObjectId('6720209c27ed2a37ccd59e3a'), ObjectId('6720209c27ed2a37ccd59e3b'), ObjectId('6720209c27ed2a37ccd59e3c'), ObjectId('6720209c27ed2a37ccd59e3d'), ObjectId('6720209c27ed2a37ccd59e3e'), ObjectId('6720209c27ed2a37ccd59e3f'), ObjectId('6720209c27ed2a37ccd59e40'), ObjectId('6720209c27ed2a37ccd59e41'),
d59e84'), ObjectId('6720209c27ed2a37ccd59e85'), ObjectId('6720209c27ed2a37ccd59e86'), ObjectId('6720209c27ed2a37ccd59e87'), ObjectId('6720209c27ed2a37ccd59e88'), ObjectId('6720209c27ed2a37ccd59e89'), ObjectId('6720209c27ed2a37ccd59e8a'), ObjectId('6720209c27ed2a37ccd59e8b'), ObjectId('6720209c27ed2a37ccd59e8c'), ObjectId('6720209c27ed2a37ccd59e8d'), ObjectId('6720209c27ed2a37ccd59e8e'), ObjectId('6720209c27ed2a37ccd59e8f'), ObjectId('6720209c27ed2a37ccd59e90'), ObjectId('6720209c27ed2a37ccd59e91'), ObjectId('6720209c27ed2a37ccd59e92'), ObjectId('6720209c27ed2a37ccd59e93'), ObjectId('6720209c27ed2a37ccd59e94'), ObjectId('6720209c27ed2a37ccd59e95'), ObjectId('6720209c27ed2a37ccd59e96'), ObjectId('6720209c27ed2a37ccd59e97'), ObjectId('6720209c27ed2a37ccd5 ...

# %% [markdown]
# ## Authors

# %%
authors = pd.read_csv('../data/processed/author_df.csv')
authors.sample()
# Out:
#         Paper ID                                        Paper Title  \
# 22159  2011-0769  HIV/AIDS and Minority Men Who Have Sex With Me...
#
#        Number of Authors  Author Position       Author Name  \
# 22159                  2                1  Patrick J Dillon
#
#                 Author Affiliation  Year
# 22159  University of South Florida  2011

# %%
authors.shape
# Out:
# (54316, 7)

# %%
author_records = authors.to_dict(orient='records')
author_records[1:3]
# Out:
# [{'Paper ID': '2003-0002',
#   'Paper Title': 'Accounting Episodes as Communicative Practice Affecting Cultural Knowledge',
#   'Number of Authors': 1,
#   'Author Position': 1,
#   'Author Name': 'Mariko Kotani',
#   'Author Affiliation': 'Aoyama Gakuin University',
#   'Year': 2003},
#  {'Paper ID': '2003-0003',
#   'Paper Title': 'Accounts of Single-fatherhood: A case study',
#   'Number of Authors': 4,
#   'Author Position': 1,
#   'Author Name': 'Tara M Emmers-Sommer',
#   'Author Affiliation': 'University of Arizona',
#   'Year': 2003}]

# %%
# authors_collection.insert_many(author_records)
# Out:
# InsertManyResult([ObjectId('6720215427ed2a37ccd6097a'), ObjectId('6720215427ed2a37ccd6097b'), ObjectId('6720215427ed2a37ccd6097c'), ObjectId('6720215427ed2a37ccd6097d'), ObjectId('6720215427ed2a37ccd6097e'), ObjectId('6720215427ed2a37ccd6097f'), ObjectId('6720215427ed2a37ccd60980'), ObjectId('6720215427ed2a37ccd60981'), ObjectId('6720215427ed2a37ccd60982'), ObjectId('6720215427ed2a37ccd60983'), ObjectId('6720215427ed2a37ccd60984'), ObjectId('6720215427ed2a37ccd60985'), ObjectId('6720215427ed2a37ccd60986'), ObjectId('6720215427ed2a37ccd60987'), ObjectId('6720215427ed2a37ccd60988'), ObjectId('6720215427ed2a37ccd60989'), ObjectId('6720215427ed2a37ccd6098a'), ObjectId('6720215427ed2a37ccd6098b'), ObjectId('6720215427ed2a37ccd6098c'), ObjectId('6720215427ed2a37ccd6098d'), ObjectId('6720215427ed2a37ccd6098e'), ObjectId('6720215427ed2a37ccd6098f'), ObjectId('6720215427ed2a37ccd60990'), ObjectId('6720215427ed2a37ccd60991'), ObjectId('6720215427ed2a37ccd60992'), ObjectId('6720215427ed2a37
# %% [markdown]
# ## Sessions

# %%
sessions = pd.read_csv('../data/processed/session_df.csv')
sessions.sample()
# Out:
#      year   session type                               session title  \
# 151  2014  Paper Session  High-Density: 2014 Interpersonal Potpourri
#
#                         sub unit   chair name  \
# 151  Interpersonal Communication  Kim Brandes
#
#                                              chair aff
# 151  Amsterdam School of Communication Research/ Un...

# %%
sessions.shape
# Out:
# (1859, 6)

# %%
session_records = sessions.to_dict(orient='records')
session_records[1:3]
# Out:
# [{'year': 2014,
#   'session type': 'Paper Session',
#   'session title': 'Cognition and Health',
#   'sub unit': 'Health Communication',
#   'chair name': 'Seth M. Noar',
#   'chair aff': 'U of North Carolina'},
#  {'year': 2014,
#   'session type': 'Paper Session',
#   'session title': "Changing the News 140 Characters At a Time: Twitter's Impact on Journalism",
#   'sub unit': 'Journalism Studies',
#   'chair name': 'Seth C. Lewis',
#   'chair aff': 'U of Minnesota'}]

# %%
# sessions_collection.insert_many(session_records)
# Out:
# InsertManyResult([ObjectId('672021af27ed2a37ccd6dda6'), ObjectId('672021af27ed2a37ccd6dda7'), ObjectId('672021af27ed2a37ccd6dda8'), ObjectId('672021af27ed2a37ccd6dda9'), ObjectId('672021af27ed2a37ccd6ddaa'), ObjectId('672021af27ed2a37ccd6ddab'), ObjectId('672021af27ed2a37ccd6ddac'), ObjectId('672021af27ed2a37ccd6ddad'), ObjectId('672021af27ed2a37ccd6ddae'), ObjectId('672021af27ed2a37ccd6ddaf'), ObjectId('672021af27ed2a37ccd6ddb0'), ObjectId('672021af27ed2a37ccd6ddb1'), ObjectId('672021af27ed2a37ccd6ddb2'), ObjectId('672021af27ed2a37ccd6ddb3'), ObjectId('672021af27ed2a37ccd6ddb4'), ObjectId('672021af27ed2a37ccd6ddb5'), ObjectId('672021af27ed2a37ccd6ddb6'), ObjectId('672021af27ed2a37ccd6ddb7'), ObjectId('672021af27ed2a37ccd6ddb8'), ObjectId('672021af27ed2a37ccd6ddb9'), ObjectId('672021af27ed2a37ccd6ddba'), ObjectId('672021af27ed2a37ccd6ddbb'), ObjectId('672021af27ed2a37ccd6ddbc'), ObjectId('672021af27ed2a37ccd6ddbd'), ObjectId('672021af27ed2a37ccd6ddbe'), ObjectId('672021af27ed2a37ccd6ddbf'), ObjectId('672021af27ed2a37ccd6ddc0'), ObjectId('672021af27ed2a37ccd6ddc1'), ObjectId('672021af27ed2a37ccd6ddc2'), ObjectId('672021af27ed2a37ccd6ddc3'), ObjectId('672021af27ed2a37ccd6ddc4'), ObjectId('672021af27ed2a37ccd6ddc5'), ObjectId('672021af27ed2a37ccd6ddc6'), ObjectId('672021af27ed2a37ccd6ddc7'), ObjectId('672021af27ed2a37ccd6ddc8'), ObjectId('672021af27ed2a37ccd6ddc9'), ObjectId('672021af27ed2a37ccd6ddca'), ObjectId('672021af27ed2a37ccd6ddcb'), ObjectId('672021af27ed2a37ccd6ddcc'), ObjectId('672021af27ed2a37ccd6ddcd'), ObjectId('672021af27ed2a37ccd6ddce'), ObjectId('672021af27ed2a37ccd6ddcf'), ObjectId('672021af27ed2a37ccd6ddd0'), ObjectId('672021af27ed2a37ccd6ddd1'), ObjectId('672021af27ed2a37ccd6ddd2'), ObjectId('672021af27ed2a37ccd6ddd3'), ObjectId('672021af27ed2a37ccd6ddd4'), ObjectId('672021af27ed2a37ccd6ddd5'), ObjectId('672021af27ed2a37ccd6ddd6'), ObjectId('672021af27ed2a37ccd6ddd7'), ObjectId('672021af27ed2a37ccd6ddd8'), ObjectId('672021af27ed2a37ccd6ddd9'), ObjectId('672021af27ed2a37ccd6ddda'), ObjectId('672021af27ed2a37ccd6dddb'), ObjectId('672021af27ed2a37ccd6dddc'), ObjectId('672021af27ed2a37ccd6dddd'), ObjectId('672021af27ed2a37ccd6ddde'), ObjectId('672021af27ed2a37ccd6dddf'), ObjectId('672021af27ed2a37ccd6dde0'), ObjectId('672021af27ed2a37ccd6dde1'), ObjectId('672021af27ed2a37ccd6dde2'), ObjectId('672021af27ed2a37ccd6dde3'), ObjectId('672021af27ed2a37ccd6dde4'), ObjectId('672021af27ed2a37ccd6dde5'), ObjectId('672021af27ed2a37ccd6dde6'), ObjectId('672021af27ed2a37ccd6dde7'), ObjectId('672021af27ed2a37ccd6dde8'), ObjectId('672021af27ed2a37ccd6dde9'), ObjectId('672021af27ed2a37ccd6ddea'), ObjectId('672021af27ed2a37ccd6ddeb'), ObjectId('672021af27ed2a37ccd6ddec'), ObjectId('672021af27ed2a37ccd6dded'), ObjectId('672021af27ed2a37ccd6ddee'), ObjectId('672021af27ed2a37ccd6ddef'), ObjectId('672021af27ed2a37ccd6ddf0'), ObjectId('672021af27ed2a37ccd6ddf1'), ObjectId('672021af27ed2a37ccd6ddf2'), ObjectId('672021af27ed2a37ccd6ddf3'), ObjectId('672021af27ed2a37ccd6ddf4'), ObjectId('672021af27ed2a37ccd6ddf5'), ObjectId('672021af27ed2a37ccd6ddf6'), ObjectId('672021af27ed2a37ccd6ddf7'), ObjectId('672021af27ed2a37ccd6ddf8'), ObjectId('672021af27ed2a37ccd6ddf9'), ObjectId('672021af27ed2a37ccd6ddfa'), ObjectId('672021af27ed2a37ccd6ddfb'), ObjectId('672021af27ed2a37ccd6ddfc'), ObjectId('672021af27ed2a37ccd6ddfd'), ObjectId('672021af27ed2a37ccd6ddfe'), ObjectId('672021af27ed2a37ccd6ddff'), ObjectId('672021af27ed2a37ccd6de00'), ObjectId('672021af27ed2a37ccd6de01'), ObjectId('672021af27ed2a37ccd6de02'), ObjectId('672021af27ed2a37ccd6de03'), ObjectId('672021af27ed2a37ccd6de04'), ObjectId('672021af27ed2a37ccd6de05'), ObjectId('672021af27ed2a37ccd6de06'), ObjectId('672021af27ed2a37ccd6de07'), ObjectId('672021af27ed2a37ccd6de08'), ObjectId('672021af27ed2a37ccd6de09'), ObjectId('672021af27ed2a37ccd6de0a'), ObjectId('672021af27ed2a37ccd6de0b'), ObjectId('672021af27ed2a37ccd6de0c'), ObjectId('672021af27ed2a37ccd6de0d'), ObjectId('672021af27ed2a37ccd6 ...
